# %%
pip install seaborn
# Out:
# ...
#
# ...

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import matplotlib.pyplot as plt


tips = sns.load_dataset('tips')

sns.barplot(x='day' , y='total_bill',data=tips)
plt.title('bar plot of toal bill day  by day')
plt.show()

# %%
sns.barplot(x='day',y='total_bill' , data=tips,ci=None)
plt.show()
# Out:
# C:\Users\97150\AppData\Local\Temp\ipykernel_11048\2859292909.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='day',y='total_bill' , data=tips,ci=None)

# %%
sns.barplot(x='day' ,y='total_bill',hue='sex',data=tips)
plt.show()

# %%
import numpy as np
sns.barplot(x='day' ,y='total_bill' ,data=tips,estimator=np.median)
plt.show()

# %%
sns.pointplot(x='day' ,y='total_bill', data=tips)
plt.show()

# %%
sns.pointplot(x='day', y='total_bill' ,hue='sex',data=tips,dodge=True)
plt.show()

# %%
sns.pointplot(x='day' ,y='total_bill' ,data=tips,estimator=np.median)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.pointplot(x='day', y='total_bill' ,hue='sex',data=tips,dodge=True)
plt.title('total bill by day and sex')
plt.ylabel('day of the week')
plt.xlabel('total bill')
plt.legend(title='sex')

plt.show()

# %%
sns.jointplot(x='total_bill' ,y='tip',data=tips,kind='scatter')
plt.title('joint plot of total bill and tip')
plt.show()

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="kde")
plt.show()

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")
plt.show()

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="hist")
plt.show()

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, hue="sex")
plt.show()

# %%
size = [15,45,25,5]
labels = ['a','b','c','d']

plt.pie(size, labels=labels,autopct='%1.1f%%',startangle=90)
plt.title('    pie chart')
plt.axis('equal')
plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)
plt.title(' linear model for total bill and tip')
plt.show()

# %%
sns.kdeplot(x='total_bill',data=tips,shade=True)
plt.title('kde plot for total bill and tips')
plt.show()
# Out:
# C:\Users\97150\AppData\Local\Temp\ipykernel_11048\4158295040.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x='total_bill',data=tips,shade=True)

# %%
sns.violinplot(x='day', y='total_bill',data=tips)
plt.title('violin plot for totall bill by day')
plt.show()

# %%
flights = sns.load_dataset('flights')
flights_pivot = flights.pivot(index='month', columns= 'year', values='passengers')


sns.heatmap(flights_pivot, cmap='coolwarm', annot=True,fmt='d')
plt.title('Heatmap of flights Data')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the flights dataset
flights = sns.load_dataset('flights')

# Create a pivot table
flights_pivot = flights.pivot(index='month',columns= 'year', values='passengers')

# Check for missing values
if flights_pivot.isnull().sum().sum() > 0:
    print("There are missing values in the pivot table.")
else:
    # Create the heatmap
    sns.heatmap(flights_pivot, cmap='coolwarm', annot=True, fmt='d')
    plt.title('Heatmap of Flights Data')
    plt.show()

# %%
sns.swarmplot(x='day', y='total_bill',data=tips)
plt.title('Swarm Plot of Total Bill by Day')
plt.show()

# %%
sns.pairplot(tips)
plt.title('pair plor of tips dtatasets')
plt.show()

# %%
sns.countplot(x='day', data=tips)
plt.title('count Plot of days')
plt.show()
