# %%
import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\97150\\Downloads\\used_cars_data.csv")

# %%
data.head()
# Out:
#                                     Name    Location  Year  Kilometers_Driven  \
# 13      Land Rover Range Rover 2.2L Pure       Delhi  2014              72000
# 14        Land Rover Freelander 2 TD4 SE        Pune  2012              85000
# 176             Mini Countryman Cooper D      Jaipur  2017               8525
# 191  Land Rover Range Rover 2.2L Dynamic  Coimbatore  2018              36091
# 228            Mini Cooper Convertible S       Kochi  2017              26327
#
#     Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  Seats  \
# 13     Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 14     Diesel    Automatic     Second    0.0 kmpl  2179 CC     115 bhp    5.0
# 176    Diesel    Automatic     Second   16.6 kmpl  1998 CC     112 bhp    5.0
# 191    Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 228    Petrol    Automatic      First  16.82 kmpl  1998 CC  189.08 bhp    4.0
#
#       New_Price  Price  cars_age        Brand              model
# 13          NaN  27.00        10   Land rover         RoverRange
# 14          NaN  17.50        12   Land rover    RoverFreelander
# 176         NaN  23.00         7  Mini Cooper   CountrymanCooper
# 191         NaN  55.76         6   Land rover         RoverRange
# 228  44.28 Lakh  35.67         7  Mini Cooper  CooperConvertible

# %%
data.shape
# Out:
# (7253, 14)

# %%
data.tail()
# Out:
#       S.No.                                               Name   Location  \
# 7248   7248                  Volkswagen Vento Diesel Trendline  Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI     Mumbai
# 7250   7250                             Nissan Micra Diesel XV    Kolkata
# 7251   7251                             Volkswagen Polo GT TSI       Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...      Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 7248  2011              89411    Diesel       Manual      First  20.54 kmpl
# 7249  2015              59000    Petrol    Automatic      First  17.21 kmpl
# 7250  2012              28000    Diesel       Manual      First  23.08 kmpl
# 7251  2013              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252  2014              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats New_Price  Price
# 7248  1598 CC  103.6 bhp    5.0       NaN    NaN
# 7249  1197 CC  103.6 bhp    5.0       NaN    NaN
# 7250  1461 CC   63.1 bhp    5.0       NaN    NaN
# 7251  1197 CC  103.6 bhp    5.0       NaN    NaN
# 7252  2148 CC    170 bhp    5.0       NaN    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7207 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %%
data.nunique()
# Out:
# S.No.                7253
# Name                 2041
# Location               11
# Year                   23
# Kilometers_Driven    3660
# Fuel_Type               5
# Transmission            2
# Owner_Type              4
# Mileage               450
# Engine                150
# Power                 386
# Seats                   9
# New_Price             625
# Price                1373
# dtype: int64

# %%
data.isnull().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# S.No.                 0.000000
# Name                  0.000000
# Location              0.000000
# Year                  0.000000
# Kilometers_Driven     0.000000
# Fuel_Type             0.000000
# Transmission          0.000000
# Owner_Type            0.000000
# Mileage               0.027575
# Engine                0.634220
# Power                 0.634220
# Seats                 0.730732
# New_Price            86.129877
# Price                17.013650
# dtype: float64

# %%
data = data.drop(['S.No.'],axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7253 non-null   object
#  1   Location           7253 non-null   object
#  2   Year               7253 non-null   int64
#  3   Kilometers_Driven  7253 non-null   int64
#  4   Fuel_Type          7253 non-null   object
#  5   Transmission       7253 non-null   object
#  6   Owner_Type         7253 non-null   object
#  7   Mileage            7251 non-null   object
#  8   Engine             7207 non-null   object
#  9   Power              7207 non-null   object
#  10  Seats              7200 non-null   float64
#  11  New_Price          1006 non-null   object
#  12  Price              6019 non-null   float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 736.8+ KB

# %%
from datetime import date
date.today().year
data['cars_age']=date.today().year-data['Year']
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price  cars_age
# 0        NaN   1.75        14
# 1        NaN  12.50         9
# 2  8.61 Lakh   4.50        13
# 3        NaN   6.00        12
# 4        NaN  17.74        11

# %%
data['Brand'] = data.Name.str.split().str.get(0)
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price  cars_age    Brand
# 0        NaN   1.75        14   Maruti
# 1        NaN  12.50         9  Hyundai
# 2  8.61 Lakh   4.50        13    Honda
# 3        NaN   6.00        12   Maruti
# 4        NaN  17.74        11     Audi

# %%
data['model'] = data.Name.str.split().str.get(1)+data.Name.str.split().str.get(2)
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price  cars_age    Brand      model
# 0        NaN   1.75        14   Maruti     WagonR
# 1        NaN  12.50         9  Hyundai   Creta1.6
# 2  8.61 Lakh   4.50        13    Honda      JazzV
# 3        NaN   6.00        12   Maruti  ErtigaVDI
# 4        NaN  17.74        11     Audi      A4New

# %%
print(data.Brand.unique())
# Out:
# ['Maruti' 'Hyundai' 'Honda' 'Audi' 'Nissan' 'Toyota' 'Volkswagen' 'Tata'
#  'Land' 'Mitsubishi' 'Renault' 'Mercedes-Benz' 'BMW' 'Mahindra' 'Ford'
#  'Porsche' 'Datsun' 'Jaguar' 'Volvo' 'Chevrolet' 'Skoda' 'Mini' 'Fiat'
#  'Jeep' 'Smart' 'Ambassador' 'Isuzu' 'ISUZU' 'Force' 'Bentley'
#  'Lamborghini' 'Hindustan' 'OpelCorsa']

# %%
print(data.Brand.nunique())
# Out:
# 33

# %%
searchfor = ['Isuzu','ISUZU','Mini','Land']
data[data.Brand.str.contains('|'.join(searchfor))].head(5)
# Out:
#                                     Name    Location  Year  Kilometers_Driven  \
# 13      Land Rover Range Rover 2.2L Pure       Delhi  2014              72000
# 14        Land Rover Freelander 2 TD4 SE        Pune  2012              85000
# 176             Mini Countryman Cooper D      Jaipur  2017               8525
# 191  Land Rover Range Rover 2.2L Dynamic  Coimbatore  2018              36091
# 228            Mini Cooper Convertible S       Kochi  2017              26327
#
#     Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  Seats  \
# 13     Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 14     Diesel    Automatic     Second    0.0 kmpl  2179 CC     115 bhp    5.0
# 176    Diesel    Automatic     Second   16.6 kmpl  1998 CC     112 bhp    5.0
# 191    Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 228    Petrol    Automatic      First  16.82 kmpl  1998 CC  189.08 bhp    4.0
#
#       New_Price  Price  cars_age Brand              model
# 13          NaN  27.00        10  Land         RoverRange
# 14          NaN  17.50        12  Land    RoverFreelander
# 176         NaN  23.00         7  Mini   CountrymanCooper
# 191         NaN  55.76         6  Land         RoverRange
# 228  44.28 Lakh  35.67         7  Mini  CooperConvertible

# %%
data['Brand'].replace({'ISUZU':'Isuzu','Mini':'Mini Cooper','Land':'Land rover'},inplace=True)

# %%
data.describe().T
# Out:
#                    count       mean           std     min      25%      50%  \
# Year                 5.0   2015.600      2.509980  2012.0   2014.0   2017.0
# Kilometers_Driven    5.0  45588.600  31959.914679  8525.0  26327.0  36091.0
# Seats                5.0      4.800      0.447214     4.0      5.0      5.0
# Price                5.0     31.786     14.950146    17.5     23.0     27.0
# cars_age             5.0      8.400      2.509980     6.0      7.0      7.0
#
#                         75%       max
# Year                2017.00   2018.00
# Kilometers_Driven  72000.00  85000.00
# Seats                  5.00      5.00
# Price                 35.67     55.76
# cars_age              10.00     12.00

# %%
data.describe(include='all').T
# Out:
#                   count unique                               top freq  \
# Name                  5      5  Land Rover Range Rover 2.2L Pure    1
# Location              5      5                             Delhi    1
# Year                5.0    NaN                               NaN  NaN
# Kilometers_Driven   5.0    NaN                               NaN  NaN
# Fuel_Type             5      2                            Diesel    4
# Transmission          5      1                         Automatic    5
# Owner_Type            5      2                             First    3
# Mileage               5      4                         12.7 kmpl    2
# Engine                5      2                           2179 CC    3
# Power                 5      4                         187.7 bhp    2
# Seats               5.0    NaN                               NaN  NaN
# New_Price             1      1                        44.28 Lakh    1
# Price               5.0    NaN                               NaN  NaN
# cars_age            5.0    NaN                               NaN  NaN
# Brand                 5      2                        Land rover    3
# model                 5      4                        RoverRange    2
#
#                       mean           std     min      25%      50%      75%  \
# Name                   NaN           NaN     NaN      NaN      NaN      NaN
# Location               NaN           NaN     NaN      NaN      NaN      NaN
# Year                2015.6       2.50998  2012.0   2014.0   2017.0   2017.0
# Kilometers_Driven  45588.6  31959.914679  8525.0  26327.0  36091.0  72000.0
# Fuel_Type              NaN           NaN     NaN      NaN      NaN      NaN
# Transmission           NaN           NaN     NaN      NaN      NaN      NaN
# Owner_Type             NaN           NaN     NaN      NaN      NaN      NaN
# Mileage                NaN           NaN     NaN      NaN      NaN      NaN
# Engine                 NaN           NaN     NaN      NaN      NaN      NaN
# Power                  NaN           NaN     NaN      NaN      NaN      NaN
# Seats                  4.8      0.447214     4.0      5.0      5.0      5.0
# New_Price              NaN           NaN     NaN      NaN      NaN      NaN
# Price               31.786     14.950146    17.5     23.0     27.0    35.67
# cars_age               8.4       2.50998     6.0      7.0      7.0     10.0
# Brand                  NaN           NaN     NaN      NaN      NaN      NaN
# model                  NaN           NaN     NaN      NaN      NaN      NaN
#
#                        max
# Name                   NaN
# Location               NaN
# Year                2018.0
# Kilometers_Driven  85000.0
# Fuel_Type              NaN
# Transmission           NaN
# Owner_Type             NaN
# Mileage                NaN
# Engine                 NaN
# Power                  NaN
# Seats                  5.0
# New_Price              NaN
# Price                55.76
# cars_age              12.0
# Brand                  NaN
# model                  NaN

# %%
cat_cols = data.select_dtypes(include=['object']).columns
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print('categorical variables:')
print(cat_cols)
print('Numerical Variables:')
print(num_cols)
# Out:
# categorical variables:
# Index(['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type',
#        'Mileage', 'Engine', 'Power', 'New_Price', 'Brand', 'model'],
#       dtype='object')
# Numerical Variables:
# ['Year', 'Kilometers_Driven', 'Seats', 'Price', 'cars_age']

# %%
for col in num_cols:
    print(col)
    print('skew:',round(data[col].skew(),2))
    plt.figure(figsize = (15,4))
    plt.subplot(1,2,1)
    data[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1,2,2)
    sns.boxplot(x=data[col])
    plt.show()
# Out:
# Year
# skew: -0.83
# Kilometers_Driven
# skew: 0.26
# Seats
# skew: -2.24
# Price
# skew: 1.26
# cars_age
# skew: 0.83

# %%
fig, axes = plt.subplots(3, 2, figsize = (18, 18))
fig.suptitle('Bar plot for all categorical variables in the dataset')
sns.countplot(ax = axes[0, 0], x = 'Fuel_Type', data = df, color = 'blue',
order = df['Fuel_Type'].value_counts().index);
sns.countplot(ax = axes[0, 1], x = 'Transmission', data = df, color = 'blue',
order = df['Transmission'].value_counts().index);
sns.countplot(ax = axes[1, 0], x = 'Owner_Type', data = df, color = 'blue',
order = df['Owner_Type'].value_counts().index);
sns.countplot(ax = axes[1, 1], x = 'Location', data = df, color = 'blue',
order = df['Location'].value_counts().index);
sns.countplot(ax = axes[2, 0], x = 'Brand', data = data, color = 'blue',
order = data['Brand'].head(20).value_counts().index);
sns.countplot(ax = axes[2, 1], x = 'model', data = data, color = 'blue',
order = data['model'].head(20).value_counts().index);
axes[1][1].tick_params(labelrotation=45);
axes[2][0].tick_params(labelrotation=90);
axes[2][1].tick_params(labelrotation=90);

# %%
print(data.columns)
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price', 'cars_age', 'Brand', 'model',
#        'Kilometers_Driven_log', 'Price_log'],
#       dtype='object')

# %%
def log_transform(df,col):
    for colname in col:
        if (df[colname] == 1.0).all():
            df[colname + '_log'] = np.log(df[colname]+1)
        else:
            df[colname + '_log'] = np.log(df[colname])
    df.info()

log_transform(df,['Kilometers_Driven','Price'])

sns.distplot(df['Kilometers_Driven_log'],axlabel = 'Kilometers_Driven-log');
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   S.No.                  7253 non-null   int64
#  1   Name                   7253 non-null   object
#  2   Location               7253 non-null   object
#  3   Year                   7253 non-null   int64
#  4   Kilometers_Driven      7253 non-null   int64
#  5   Fuel_Type              7253 non-null   object
#  6   Transmission           7253 non-null   object
#  7   Owner_Type             7253 non-null   object
#  8   Mileage                7251 non-null   object
#  9   Engine                 7207 non-null   object
#  10  Power                  7207 non-null   object
#  11  Seats                  7200 non-null   float64
#  12  New_Price              1006 non-null   object
#  13  Price                  6019 non-null   float64
#  14  Kilometers_Driven_log  7253 non-null   float64
#  15  Price_log              6019 non-null   float64
# dtypes: float64(4), int64(3), object(9)
# memory usage: 906.8+ KB
# C:\Users\97150\AppData\Local\Temp\ipykernel_18472\1744214047.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Kilometers_Driven_log'],axlabel = 'Kilometers_Driven-log');

# %%
plt.figure(figsize=(13,17))
sns.pairplot(data=df.drop(['Kilometers_Driven','Price'],axis=1))
plt.show()

# %%
fig, axarr = plt.subplots(4, 2, figsize=(12, 18))
df.groupby('Location')
['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[0][0], fontsize=12)
axarr[0][0].set_title("Location Vs Price", fontsize=18)
df.groupby('Transmission')
['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[0][1], fontsize=12)
axarr[0][1].set_title("Transmission Vs Price", fontsize=18)
df.groupby('Fuel_Type')
['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[1][0], fontsize=12)
axarr[1][0].set_title("Fuel_Type Vs Price", fontsize=18)
df.groupby('Owner_Type')
['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[1][1], fontsize=12)
axarr[1][1].set_title("Owner_Type Vs Price", fontsize=18)
df.groupby('Brand')
['Price_log'].mean().sort_values(ascending=False).head(10).plot.bar(ax=axarr[2][0],
fontsize=12)
axarr[2][0].set_title("Brand Vs Price", fontsize=18)
df.groupby('Model')
['Price_log'].mean().sort_values(ascending=False).head(10).plot.bar(ax=axarr[2][1],
fontsize=12)
axarr[2][1].set_title("Model Vs Price", fontsize=18)
df.groupby('Seats')
['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[3][0], fontsize=12)
axarr[3][0].set_title("Seats Vs Price", fontsize=18)
df.groupby('Car_Age')
['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[3][1], fontsize=12)
axarr[3][1].set_title("Car_Age Vs Price", fontsize=18)
plt.subplots_adjust(hspace=1.0)
plt.subplots_adjust(wspace=.5)
sns.despine()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[248], line 3
#       1 fig, axarr = plt.subplots(4, 2, figsize=(12, 18))
#       2 df.groupby('Location')
# ----> 3 ['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[0][0], fontsize=12)
#       4 axarr[0][0].set_title("Location Vs Price", fontsize=18)
#       5 df.groupby('Transmission')
#
# AttributeError: 'list' object has no attribute 'mean'

# %%
numeric_data = data.drop(['Kilometers_Driven', 'Price'], axis=1).select_dtypes(include=[np.number])
plt.figure(figsize=(12,7))
sns.heatmap(numeric_data.corr(),annot = True, vmin = -1,vmax=1)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


numeric_data = df.drop(['Kilometers_Driven', 'Price'], axis=1).select_dtypes(include=[np.number])


plt.figure(figsize=(12,7))
sns.heatmap(numeric_data.corr(), annot=True, vmin=-1, vmax=1)
plt.show()
